# %% [markdown]
# Observations
#
# To be honest, the visualizations didn’t make a lot of sense to me. I was expecting them to look more organized and clear, but since we were working with real-world data, some parts just didn’t add up or made sense.
#
# One of the first things I struggled with was uploading the dataset. I didn’t realize I had to upload the actual Excel file from the classroom homepage. I asked ChatGPT how to upload a dataset to Google Colab, and it walked me through the process step by step, that really helped.
#
# Once I got the data uploaded, things slowly started to make more senses. The codes you provided in the Python Overview were super helpful and made it easier to follow along.
#
# Installing the necessary libraries also took me a bit of time, but I eventually figured it out. One thing I thought was really cool was how Google Colab handles errors—when something goes wrong, it actually gives you suggestions on how to fix them.
#
# Overall, the easiest parts of the assignment was uploading the dataset (once I figured it out) and getting the libraries installed. As for the visualizations, I found the histogram to be the easiest to read and also the best-looking one once it was generated.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("creditcard.csv")
print(df.head())

df.describe()

plt.figure(figsize=(8, 4))
sns.boxplot(df['Amount'], color='orange')
plt.title('fraud vs. non-fraud')
plt.show()

from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats.mstats import winsorize

plt.figure(figsize=(12, 6))
plt.subplot(121)
sns.histplot(df['Amount'], kde=True, color='blue')
plt.title('Fraud')

plt.subplot(122)
sns.histplot(df['Class'], kde=True, color='green')
plt.title('Non-Fraud')
plt.show()

plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt="2f")
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...
